# %%
import pandas as pd

df = pd.read_csv("exemplo_casas.csv")

# Primeiros registros
print("amostras:", df.head())
# Out:
# amostras:    Id                                             Titulo  Endereço  \
# 0   1  https://www.vivareal.com.br/imovel/casa-2-quar...       NaN
# 1   2  https://www.vivareal.com.br/imovel/casa-3-quar...       NaN
# 2   3  https://www.vivareal.com.br/imovel/casa-2-quar...       NaN
# 3   4  https://www.vivareal.com.br/imovel/casa-2-quar...       NaN
# 4   5  https://www.vivareal.com.br/imovel/casa-2-quar...       NaN
#
#    Metragem construida                  OBS          Valor  \
# 0                  100       Casa reformada  R$ 267.000,00
# 1                  168   Precisa de Reforma  R$ 300.000,00
# 2                  114  sobrado. Parece bom  R$ 245.000,00
# 3                  100     Armário embutido  R$ 295.000,00
# 4                  175           Parece boa  R$ 450.000,00
#
#   Preço do m² construído
# 0            R$ 2.670,00
# 1            R$ 1.785,71
# 2            R$ 2.149,12
# 3            R$ 2.950,00
# 4            R$ 2.571,43
